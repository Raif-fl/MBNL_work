# %%
import pandas as pd

# %%
CVB24_MBNL1 = pd.read_csv("~/projects/MBNL_skipper/skipper_analysis/output/reproducible_enriched_windows/CVB24_MBNL1.reproducible_enriched_windows.tsv.gz",
           sep = "\t")

# %%
CVB24_MBNL1.columns
# Out:
# Index(['chr', 'start', 'end', 'name', 'score', 'strand', 'gc', 'gc_bin',
#        'chrom', 'feature_id', 'feature_bin', 'feature_type_top',
#        'feature_types', 'gene_name', 'gene_id', 'transcript_ids',
#        'gene_type_top', 'transcript_type_top', 'gene_types',
#        'transcript_types', 'input_sum', 'clip_sum', 'enrichment_n',
#        'enrichment_l2or_min', 'enrichment_l2or_mean', 'enrichment_l2or_max',
#        'p_max', 'p_min', 'q_max', 'q_min'],
#       dtype='object')

# %%
CVB24_MBNL1[['chr', 'start', 'end', 'chrom', 'gene_name', 'input_sum', 'clip_sum', 'enrichment_n',
       'enrichment_l2or_min', 'enrichment_l2or_mean', 'enrichment_l2or_max',
       'p_max', 'p_min', 'q_max', 'q_min']]
# Out:
#         chr      start        end  chrom        gene_name  input_sum  \
# 0      chrX   63350535   63350627   chrX  LINC01278:SPIN4          0
# 1      chrX   63350535   63350627   chrX  LINC01278:SPIN4          0
# 2      chr1   61161225   61161325   chr1             NFIA          0
# 3      chr2  235948593  235948693   chr2            AGAP1          1
# 4      chr2  235948593  235948693   chr2            AGAP1          1
# ...     ...        ...        ...    ...              ...        ...
# 7936  chr20   58910015   58910081  chr20             GNAS        379
# 7937  chr11   65501159   65501258  chr11           MALAT1        246
# 7938  chr11   65502151   65502250  chr11           MALAT1        343
# 7939  chr20   58905382   58905480  chr20             GNAS        783
# 7940   chr3  151188053  151188153   chr3           MED12L      33005
#
#       clip_sum  enrichment_n  enrichment_l2or_min  enrichment_l2or_mean  \
# ...
